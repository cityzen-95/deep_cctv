# %%
import os
  
file_path = 'C:\\darknet-master\\build\\darknet\\x64\\data\\img'
file_names = os.listdir(file_path)

# %%
cwd = os.getcwd()
print(cwd)
# Out:
# C:\Users\KIM\deep_cctv

# %%
i = 0
for name in file_names:
    src = os.path.join(file_path, name)
    dst = 'Mask_' + str(i+679) + '.txt'
    dst = os.path.join(file_path, dst)
    os.rename(src, dst)
    i += 1

# %%
for k in range(679, 1501):
    print('data/img/Mask_'+str(k)+'.jpg')
# Out:
# data/img/Mask_679.jpg
# data/img/Mask_680.jpg
# data/img/Mask_681.jpg
# data/img/Mask_682.jpg
# data/img/Mask_683.jpg
# data/img/Mask_684.jpg
# data/img/Mask_685.jpg
# data/img/Mask_686.jpg
# data/img/Mask_687.jpg
# data/img/Mask_688.jpg
# data/img/Mask_689.jpg
# data/img/Mask_690.jpg
# data/img/Mask_691.jpg
# data/img/Mask_692.jpg
# data/img/Mask_693.jpg
# data/img/Mask_694.jpg
# data/img/Mask_695.jpg
# data/img/Mask_696.jpg
# data/img/Mask_697.jpg
# data/img/Mask_698.jpg
# data/img/Mask_699.jpg
# data/img/Mask_700.jpg
# data/img/Mask_701.jpg
# data/img/Mask_702.jpg
# data/img/Mask_703.jpg
# data/img/Mask_704.jpg
# data/img/Mask_705.jpg
# data/img/Mask_706.jpg
# data/img/Mask_707.jpg
# data/img/Mask_708.jpg
# data/img/Mask_709.jpg
# data/img/Mask_710.jpg
# data/img/Mask_711.jpg
# data/img/Mask_712.jpg
# data/img/Mask_713.jpg
# data/img/Mask_714.jpg
# data/img/Mask_715.jpg
# data/img/Mask_716.jpg
# data/img/Mask_717.jpg
# data/img/Mask_718.jpg
# data/img/Mask_719.jpg
# ...
